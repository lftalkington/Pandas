# %% [markdown]
# # PyCity Schools Analysis
#
# * As a whole, schools with higher budgets, did not yield better test results. By contrast, schools with higher spending per student actually (\$645-675) underperformed compared to schools with smaller budgets (<\$585 per student).
#
# * As a whole, smaller and medium sized schools dramatically out-performed large sized schools on passing math performances (89-91% passing vs 67%).
#
# * As a whole, charter schools out-performed the public district schools across all metrics. However, more analysis will be required to glean if the effect is due to school practices or the fact that charter schools tend to serve smaller student populations per school.
# ---

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import os

# File to Load (Remember to Change These)
school_data_csv = "Resources/schools_complete.csv"
student_data_csv = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas Data Frames
school_data = pd.read_csv(school_data_csv)
student_data = pd.read_csv(student_data_csv)

# Combine the data into a single dataset
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
student_data.columns
# Out:
# Index(['Student ID', 'student_name', 'gender', 'grade', 'school_name',
#        'reading_score', 'math_score'],
#       dtype='object')

# %%
# number_of_schools = school_data_complete
number_of_schools = len(school_data)
number_of_schoscols
# Out:
# 15

# %%
student_id = school_data_complete["Student ID"].nunique()
student_id
# Out:
# 39170

# %%
budget = school_data["budget"].sum()
budget
# Out:
# 24649428

# %%
av_math = student_data["math_score"].mean()
av_math
# Out:
# 78.98537145774827

# %%
av_reading = student_data["reading_score"].mean()
av_reading
# Out:
# 81.87784018381414

# %%
# Calculate the overall passing rate (overall average score), i.e. (avg. math score + avg. reading score)/2
math_and_reading = av_math + av_reading
overall_passing_rate = math_and_reading / 2
overall_passing_rate
# Out:
# 80.43160582078121

# %%
# percentage of students with a passing math score (70 or greater)
percent_math = (student_data["math_score"] > 70).sum()/(student_data["math_score"].count())*100
percent_math
# Out:
# 72.39213683941792

# %%
# passing reading score (70 or greater)
percent_reading = (student_data["reading_score"] > 70).sum()/(student_data["reading_score"]).count()*100
percent_reading
# Out:
# 82.97166198621395

# %%
#create a summary table
#missing name of school and school type

summary_df = pd.DataFrame({'Total Schools': [number_of_schools], 
                           'Total Students': [student_id],
                           'Total Budget': [budget],
                           'Average Math Score': [av_math],
                           'Average Reading Score': [av_reading],
                          '%Math': [percent_math],
                          '%Reading': [percent_reading],
                          '%Passing Rate': [overall_passing_rate]})
summary_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.985371
#
#    Average Reading Score      %Math   %Reading  %Passing Rate
# 0               81.87784  72.392137  82.971662      80.431606

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)
#
# * Create a dataframe to hold the above results

# %%
#individual school data
individual_school_data_df = student_data.groupby (["school_name"], as_index=False)
individual_school_data_df.head()
# Out:
#        Student ID       student_name gender grade            school_name  \
# 0               0       Paul Bradley      M   9th      Huang High School
# 1               1       Victor Smith      M  12th      Huang High School
# 2               2    Kevin Rodriguez      M  12th      Huang High School
# 3               3  Dr. Richard Scott      M  12th      Huang High School
# 4               4         Bonnie Ray      F   9th      Huang High School
# 2917         2917         Amy Jacobs      F  10th   Figueroa High School
# 2918         2918    Nathan Campbell      M  12th   Figueroa High School
# 2919         2919    Randall Stewart      M  12th   Figueroa High School
# 2920         2920     Jennifer Brown      F   9th   Figueroa High School
# 2921         2921       Denise Lopez      F  10th   Figueroa High School
# 5866         5866   Jamie Montgomery      F  12th    Shelton High School
# 5867         5867   Shannon Phillips      F  10th    Shelton High School
# ...

# %%
#school type & name -- how do I put a space in this?
school_name_and_type = school_data["type"] + school_data["school_name"]
school_name_and_type
# Out:
# 0         DistrictHuang High School
# 1      DistrictFigueroa High School
# 2        CharterShelton High School
# 3     DistrictHernandez High School
# 4        CharterGriffin High School
# 5         CharterWilson High School
# 6        CharterCabrera High School
# 7        DistrictBailey High School
# 8         CharterHolden High School
# 9           CharterPena High School
# 10        CharterWright High School
# 11    DistrictRodriguez High School
# 12      DistrictJohnson High School
# 13         DistrictFord High School
# 14        CharterThomas High School
# dtype: object

# %%
#av math
av_math_indiv = pd.DataFrame(individual_school_data_df["math_score"].mean())
av_math_indiv
# Out:
#               school_name  math_score
# 0      Bailey High School   77.048432
# 1     Cabrera High School   83.061895
# 2    Figueroa High School   76.711767
# 3        Ford High School   77.102592
# 4     Griffin High School   83.351499
# 5   Hernandez High School   77.289752
# 6      Holden High School   83.803279
# 7       Huang High School   76.629414
# 8     Johnson High School   77.072464
# 9        Pena High School   83.839917
# 10  Rodriguez High School   76.842711
# 11    Shelton High School   83.359455
# 12     Thomas High School   83.418349
# 13     Wilson High School   83.274201
# 14     Wright High School   83.682222

# %%
#av reading
av_reading_indiv = pd.DataFrame(individual_school_data_df["reading_score"].mean())
av_reading_indiv
# Out:
#               school_name  reading_score
# 0      Bailey High School      81.033963
# 1     Cabrera High School      83.975780
# 2    Figueroa High School      81.158020
# 3        Ford High School      80.746258
# 4     Griffin High School      83.816757
# 5   Hernandez High School      80.934412
# 6      Holden High School      83.814988
# 7       Huang High School      81.182722
# 8     Johnson High School      80.966394
# 9        Pena High School      84.044699
# 10  Rodriguez High School      80.744686
# 11    Shelton High School      83.725724
# 12     Thomas High School      83.848930
# 13     Wilson High School      83.989488
# 14     Wright High School      83.955000

# %%
# % math

    math_pass = student_data[student_data["math_score"]>70].groupby(["school_name"], as_index=False)
    math_pass

    # #total math
    indiv_math_pass = pd.DataFrame(math_pass["math_score"].count())
    indiv_math_pass.columns= ["school_name", "Pass Math Count"]
    indiv_math_pass
# Out:
#               school_name  Pass Math Count
# 0      Bailey High School             3216
# 1     Cabrera High School             1664
# 2    Figueroa High School             1880
# 3        Ford High School             1801
# 4     Griffin High School             1317
# 5   Hernandez High School             3001
# 6      Holden High School              387
# 7       Huang High School             1847
# 8     Johnson High School             3040
# 9        Pena High School              882
# 10  Rodriguez High School             2562
# 11    Shelton High School             1583
# 12     Thomas High School             1475
# 13     Wilson High School             2076
# 14     Wright High School             1625

# %%
# Add calculated columns for math percent pass
indiv_math_pass["Pass Math Count"] = (indiv_math_pass["Pass Math Count"]/school_data_complete["size"])*100
indiv_math_pass
# Out:
#               school_name  Pass Math Count
# 0      Bailey High School       110.250257
# 1     Cabrera High School        57.044909
# 2    Figueroa High School        64.449777
# 3        Ford High School        61.741515
# 4     Griffin High School        45.149126
# 5   Hernandez High School       102.879671
# 6      Holden High School        13.267055
# 7       Huang High School        63.318478
# 8     Johnson High School       104.216661
# 9        Pena High School        30.236544
# 10  Rodriguez High School        87.829962
# 11    Shelton High School        54.268084
# 12     Thomas High School        50.565650
# 13     Wilson High School        71.169009
# 14     Wright High School        55.707919

# %%
reading_pass = student_data[student_data["reading_score"]>70].groupby(["school_name"], as_index=False)
reading_pass

#total reading
indiv_reading_pass = pd.DataFrame(reading_pass["reading_score"].count())
indiv_reading_pass.columns= ["school_name", "Pass Reading Count"]
indiv_reading_pass
# Out:
#               school_name  Pass Reading Count
# 0      Bailey High School                3946
# 1     Cabrera High School                1744
# 2    Figueroa High School                2313
# 3        Ford High School                2123
# 4     Griffin High School                1371
# 5   Hernandez High School                3624
# 6      Holden High School                 396
# 7       Huang High School                2299
# 8     Johnson High School                3727
# 9        Pena High School                 887
# 10  Rodriguez High School                3109
# 11    Shelton High School                1631
# 12     Thomas High School                1519
# 13     Wilson High School                2129
# 14     Wright High School                1682

# %%
# Add calculated columns for math percent pass
indiv_reading_pass["Pass Reading Count"] = (indiv_reading_pass["Pass Reading Count"]/school_data_complete["size"])*100
indiv_reading_pass
# Out:
#               school_name  Pass Reading Count
# 0      Bailey High School          135.275968
# 1     Cabrera High School           59.787453
# 2    Figueroa High School           79.293795
# 3        Ford High School           72.780254
# 4     Griffin High School           47.000343
# 5   Hernandez High School          124.237230
# 6      Holden High School           13.575591
# 7       Huang High School           78.813850
# 8     Johnson High School          127.768255
# 9        Pena High School           30.407953
# 10  Rodriguez High School          106.582105
# 11    Shelton High School           55.913610
# 12     Thomas High School           52.074049
# 13     Wilson High School           72.985944
# 14     Wright High School           57.661981

# %%
#average passing of both reading and math combined
school_data_complete["Over All Pass Percentage"] = (indiv_math_pass["Pass Math Count"]+indiv_reading_pass["Pass Reading Count"])/2
school_data_complete
# Out:
#        Student ID         student_name gender grade         school_name  \
# 0               0         Paul Bradley      M   9th   Huang High School
# 1               1         Victor Smith      M  12th   Huang High School
# 2               2      Kevin Rodriguez      M  12th   Huang High School
# 3               3    Dr. Richard Scott      M  12th   Huang High School
# 4               4           Bonnie Ray      F   9th   Huang High School
# 5               5        Bryan Miranda      M   9th   Huang High School
# 6               6        Sheena Carter      F  11th   Huang High School
# 7               7         Nicole Baker      F  12th   Huang High School
# 8               8         Michael Roth      M  10th   Huang High School
# 9               9       Matthew Greene      M  10th   Huang High School
# 10             10     Andrew Alexander      M  10th   Huang High School
# 11             11        Daniel Cooper      M  10th   Huang High School
# ...

# %%
#total students
total_students = school_data_complete["school_name"].value_counts()
total_students
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
#indiv budget per school
indiv_school_budget = school_data_complete['budget'].mean()
budget_per_student = indiv_school_budget / total_students
budget_per_student
# Out:
# Bailey High School        425.490553
# Johnson High School       444.705102
# Hernandez High School     456.794172
# Rodriguez High School     529.442608
# Figueroa High School      717.952184
# Huang High School         725.828245
# Ford High School          772.997806
# Wilson High School        927.394214
# Cabrera High School      1139.526905
# Wright High School       1176.244994
# Shelton High School      1202.294713
# Thomas High School       1294.948617
# Griffin High School      1442.262254
# Pena High School         2200.874209
# Holden High School       4958.409811
# Name: school_name, dtype: float64

# %%
individual_summary_df = pd.DataFrame({'School Name & Type': [school_name_and_type], 
                           'Total Students': [total_students],
                           'Total Budget': [budget_per_student],
                           'Average Math Score': [av_math_indiv],
                           'Average Reading Score': [av_reading_indiv],
                            '%Math': [indiv_math_pass],
                          '%Reading': [indiv_reading_pass],
                          'Overall Passing Rate': [overall_passing_rate]})
individual_summary_df

#   '%Passing Rate': [overall_passing_rate]
# Out:
#                                   School Name & Type  \
# 0  0         DistrictHuang High School
# 1      Dis...
#
#                                       Total Students  \
# 0  Bailey High School       4976
# Johnson High Sch...
#
#                                         Total Budget  \
# 0  Bailey High School        425.490553
# Johnson H...
#
#                                   Average Math Score  \
# 0                school_name  math_score
# 0      B...
#
#                                Average Reading Score  \
# 0                school_name  reading_score
# 0    ...
#
#                                                %Math  \
# 0                school_name  Pass Math Count
# 0  ...
#
#                                             %Reading  Overall Passing Rate
# 0                school_name  Pass Reading Count
# ...             80.431606

# %% [markdown]
# ## Top Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the top five schools in overall passing rate

# %%
Top_schools = school_data_complete.sort_values(
    ["Over All Pass Percentage"], ascending=False)
Top_schools.head()
# Out:
#     Student ID      student_name gender grade        school_name  \
# 0            0      Paul Bradley      M   9th  Huang High School
# 8            8      Michael Roth      M  10th  Huang High School
# 5            5     Bryan Miranda      M   9th  Huang High School
# 10          10  Andrew Alexander      M  10th  Huang High School
# 13          13      William Long      M   9th  Huang High School
#
#     reading_score  math_score  School ID      type  size   budget  \
# 0              66          79          0  District  2917  1910635
# 8              95          87          0  District  2917  1910635
# 5              94          94          0  District  2917  1910635
# 10             90          70          0  District  2917  1910635
# 13             71          79          0  District  2917  1910635
#
#     Over All Pass Percentage
# 0                 122.763113
# 8                 115.992458
# 5                 113.558450
# 10                 97.206034
# ...

# %% [markdown]
# ## Bottom Performing Schools (By Passing Rate)

# %% [markdown]
# * Sort and display the five worst-performing schools

# %%
Bottom_schools = school_data_complete.sort_values(["Over All Pass Percentage"], ascending=True)
Bottom_schools.head()
# Out:
#     Student ID     student_name gender grade        school_name  \
# 6            6    Sheena Carter      F  11th  Huang High School
# 9            9   Matthew Greene      M  10th  Huang High School
# 4            4       Bonnie Ray      F   9th  Huang High School
# 12          12  Brittney Walker      F   9th  Huang High School
# 11          11    Daniel Cooper      M  10th  Huang High School
#
#     reading_score  math_score  School ID      type  size   budget  \
# 6              82          80          0  District  2917  1910635
# 9              96          84          0  District  2917  1910635
# 4              97          84          0  District  2917  1910635
# 12             64          79          0  District  2917  1910635
# 11             78          77          0  District  2917  1910635
#
#     Over All Pass Percentage
# 6                  13.421323
# 9                  30.322249
# 4                  46.074734
# 12                 51.319849
# 11                 55.090847

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# students_gr_grade_df = student_data.groupby(['school name','grade']).reading_score.mean().unstack(level=1)
# students_gr_grade_df

nineth_grade = school_data_complete[(school_data_complete["grade"] == "9th")]
tenth_grade = school_data_complete[(school_data_complete["grade"] == "10th")]
eleventh_grade = school_data_complete[(school_data_complete["grade"] == "11th")]
twelfth_grade = school_data_complete[(school_data_complete["grade"] == "12th")]

nineth_graders_scores = nineth_grade.groupby(["school_name"]).mean()["math_score"]
tenth_graders_scores = tenth_grade.groupby(["school_name"]).mean()["math_score"]
eleventh_graders_scores = eleventh_grade.groupby(["school_name"]).mean()["math_score"]
twelfth_graders_scores = twelfth_grade.groupby(["school_name"]).mean()["math_score"]


scores_by_grade_df = pd.DataFrame({"9th": nineth_graders_scores,
                                "10th":tenth_graders_scores,
                                "11th":eleventh_graders_scores,
                                "12th":twelfth_graders_scores
                                
                                
 
    
    
})



scores_by_grade_df.index.name = None

scores_by_grade_df = scores_by_grade_df [["9th", "10th", "11th", "12th"]]


scores_by_grade_df
# Out:
#                              9th       10th       11th       12th
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School     83.590022  83.087886  83.498795  83.497041
# ...

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# students_gr_grade_df = student_data.groupby(['school name','grade']).reading_score.mean().unstack(level=1)
# students_gr_grade_df

nineth_graders = school_data_complete[(school_data_complete["grade"] == "9th")]
tenth_graders = school_data_complete[(school_data_complete["grade"] == "10th")]
eleventh_graders = school_data_complete[(school_data_complete["grade"] == "11th")]
twelfth_graders = school_data_complete[(school_data_complete["grade"] == "12th")]

nineth_graders_scores = nineth_graders.groupby(["school_name"]).mean()["reading_score"]
tenth_graders_scores = tenth_graders.groupby(["school_name"]).mean()["reading_score"]
eleventh_graders_scores = eleventh_graders.groupby(["school_name"]).mean()["reading_score"]
twelfth_graders_scores = twelfth_graders.groupby(["school_name"]).mean()["reading_score"]


scores_by_grade_df = pd.DataFrame({"9th": nineth_graders_scores,
                                "10th":tenth_graders_scores,
                                "11th":eleventh_graders_scores,
                                "12th":twelfth_graders_scores
                                
                                
 
    
    
})



scores_by_grade_df.index.name = None

scores_by_grade_df = scores_by_grade_df [["9th", "10th", "11th", "12th"]]


scores_by_grade_df
# Out:
#                              9th       10th       11th       12th
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School     83.728850  84.254157  83.585542  83.831361
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
school_data.columns
# Out:
# Index(['School ID', 'school_name', 'type', 'size', 'budget'], dtype='object')

# %%
# # Sample bins. Feel free to create your own bins.
spending_bins = [0, 585, 615, 645, 675]
group_names = ["<$585", "$585-615", "$615-645", "$645-675"]

school_data_complete["Spending Range"]=pd.cut(school_data_complete["budget"], spending_bins, labels=group_names)
spending = school_data_complete.loc[:, "Spending Range", "av_math", "av_reading", "%math_pass", "%reading_pass", "overall_passing_rate"].groupby("Spending Range")
spending.mean
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-95-7171d49896a3> in <module>
#       4
#       5 school_data_complete["Spending Range"]=pd.cut(school_data_complete["budget"], spending_bins, labels=group_names)
# ----> 6 spending = school_data_complete.loc[:, "Spending Range", "av_math", "av_reading", "%math_pass", "%reading_pass", "overall_passing_rate"].groupby("Spending Range")
#       7 spending.mean
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1470             except (KeyError, IndexError):
#    1471                 pass
# -> 1472             return self._getitem_tuple(key)
#    1473         else:
#    1474             # we by definition only have the 0th axis
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#     873
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Sample bins. Feel free to create your own bins.
size_bins = [0, 1000, 2000, 5000]
group_names = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
score_by_size = summary_df[["av_math", "av_reading", "math_pass", "reading_pass", "overall_passing_rate"]].groupby, bins=bins, labels=group_names).mean()
score_by_size.head()
# Out:
#   File "<ipython-input-101-9f93e345ddff>", line 1
#     score_by_size = summary_df[["av_math", "av_reading", "math_pass", "reading_pass", "overall_passing_rate"]].groupby, bins=bins, labels=group_names).mean()
#                                                                                                                                                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type.

# %%
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.473852              83.896421       93.620830
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing Rate
# School Type
# Charter              96.586489               95.103660
# District             80.799062               73.673757
